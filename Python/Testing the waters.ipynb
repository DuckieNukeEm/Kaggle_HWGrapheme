# %% [markdown]
# # Just testing the waters

# %%
import pandas as pd
import numpy as np
import os as os
import matplotlib.pyplot as plt

# %%
Df = pd.read_parquet('../Data/train_image_data_0.parquet')

# %%
Df.shape
# Out:
# (50210, 32333)

# %%
RR = Df.iloc[1,1:].values.astype(float)

# %%
RR.reshape(137,236)
# Out:
# array([[251., 244., 238., ..., 255., 255., 255.],
#        [252., 252., 250., ..., 255., 255., 255.],
#        [248., 248., 250., ..., 255., 255., 255.],
#        ...,
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 254.],
#        [255., 255., 255., ..., 255., 255., 254.]])

# %%
plt.imshow(255 - RR.reshape(137,236))

# %%
Df.iloc[:,1
# Out:
# count    50210.000000
# mean       245.727066
# std         12.885159
# min         48.000000
# 25%        246.000000
# 50%        250.000000
# 75%        252.000000
# max        255.000000
# Name: 0, dtype: float64

# %%
TT = Df.iloc[40040:40060,1:].sum()
TT = TT/TT.shape[0]

# %%
TT.shape[0]
# Out:
# 32332

# %%
plt.imshow(255 - TT.values.reshape(137,236))

# %%
Df.to_csv('../Data/TID0.csv')
